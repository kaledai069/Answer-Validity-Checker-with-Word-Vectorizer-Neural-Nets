# %% [markdown]
# <a href="https://colab.research.google.com/github/kaledai069/Answer-Validity-Checker-with-Word-Vectorizer-Neural-Nets/blob/master/Alternate_Solution_Ranker_Comparing_scoring_capability_between_ByT5_(BCS)_and_T5_Small_(One_Full_Epoch_Trained).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !pip install -q pyspellchecker
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 12.2 MB/s eta 0:00:00

# %%
import torch
import pandas as pd
import random
import os
import time
import string

from tqdm import tqdm
from spellchecker import SpellChecker
from transformers import T5ForConditionalGeneration, AutoTokenizer, BartForConditionalGeneration, BartTokenizer

# %%
DATASET_PATH = "/content/gdrive/MyDrive/Clue-Answer Dataset/CLUE_ANSWER_DATA_VERSION_1.csv"
T5_RANKER_PATH = "/content/gdrive/MyDrive/Second Pass Model/t5_word_segmented_pair_2_epochs/"
BYT5_RANKER_PATH = "/content/gdrive/MyDrive/Second Pass Model/byt5_reranker/"
BART_RANKER_PATH = "/content/gdrive/MyDrive/Second Pass Model/bart-base-model-3M-one_epoch/"

# %%
# loading the dataset in a df and sampling random chunk for observation
clue_answer_df = pd.read_csv(DATASET_PATH)

# %%
sample_size = 2000
sample_df = clue_answer_df.sample(n = sample_size, random_state = 69)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# ByT5-small as the reranker model from Huggingface (BCS)
MODEL_BYT5 = 'google/byt5-small'
tokenizer_byt5 = AutoTokenizer.from_pretrained(MODEL_BYT5)
model_byt5 = T5ForConditionalGeneration.from_pretrained(BYT5_RANKER_PATH)

# T5-small as the reranker model trained with own data (3 Million Clue-Answer Pair)
MODEL_T5 = 't5-small'
tokenizer_t5 = AutoTokenizer.from_pretrained(MODEL_T5)
model_t5 = T5ForConditionalGeneration.from_pretrained(T5_RANKER_PATH)

# Bart-base as the reranker model trained for a single epoch on 3M clue-answer pair
MODEL_BART = 'facebook/bart-base'
tokenizer_bart = BartTokenizer.from_pretrained(MODEL_BART)
model_bart = BartForConditionalGeneration.from_pretrained(BART_RANKER_PATH)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.59k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/698 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.50k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.72k [00:00<?, ?B/s]

# %%
def inference_model(model_, tokenizer_, clue, answer, model_type):
  with torch.inference_mode():
    if model_type == 'byt5':
      inputs = tokenizer_(['Q: ' + clue], return_tensors='pt')['input_ids']

    else: # i.e. T5-small
      # cause i didn't use above like format for clue in the T5-small training
      inputs = tokenizer_(['Q: ' + clue], return_tensors='pt')['input_ids']

    labels = tokenizer_([answer], return_tensors='pt')['input_ids']
    loss = model_(inputs, labels = labels)
    answer_length = labels.shape[1]
    logprob = -loss[0].item() * answer_length
    return logprob

# %%
# comparing side-by-side results between ByT5 and Bart-base
result_df_list = []
num_samples = 10
for _ in range(num_samples):
  random_index = random.randint(0, len(sample_df) - 1)
  clue = sample_df['clue'].iloc[random_index]
  answer = sample_df['answer'].iloc[random_index]

  start_t = time.time()
  byt5_score = inference_model(model_byt5, tokenizer_byt5, clue, answer, "byt5")
  byt5_inf_time = time.time() - start_t

  start_t = time.time()
  bart_score = inference_model(model_bart, tokenizer_bart, clue, answer, "bart")
  bart_inf_time = time.time() - start_t

  result_df_list.append((clue, answer, byt5_score, bart_score, byt5_inf_time, bart_inf_time, byt5_inf_time / bart_inf_time))

result_df = pd.DataFrame(result_df_list, columns = ["Clue", 'Answer', 'ByT5 Score', 'BART Score', 'BART Inference Time', 'BART Inference Time', 'BART Time Factor'])
print(f"T5_small Model is {int(result_df['BART Time Factor'].mean())} times faster than ByT5_small for single inference.")

result_df.head(10)
# Out:
# T5_small Model is 4 times faster than ByT5_small for single inference.
#                                                 Clue      Answer  ByT5 Score  \
# 0                            robert mueller's agency     the fbi  -36.811340
# 1                    chuck (charles) lamb is a plant     lobelia   -5.852175
# 2                                 called one's bluff       dared   -5.698220
# 3                           an ___ of prevention....       ounce   -0.005506
# 4                                 joad family seeker        to m  -55.757532
# 5                like 2018's hereditary, for example       eerie   -6.568623
# 6                  the impression one gives is false   imitation  -12.021878
# 7                 la cenerentola composer and family   rossin is  -68.485556
# 8       1956 star of vadim's "and god created woman"      bardot   -8.875616
# 9  y using indian's skin over colour, chiefly, th...  inhumanely  -20.323250
#
#    BART Score  BART Inference Time  BART Inference Time  BART Time Factor
# 0   -4.446746             1.302998             0.362882          3.590693
# 1   -4.254205             0.857822             0.223972          3.830044
# 2   -4.843416             0.677315             0.179946          3.763986
# 3   -0.017474             0.543561             0.138816          3.915696
# 4  -18.012772             0.484505             0.143193          3.383567
# 5   -8.998318             0.610896             0.143132          4.268066
# 6   -4.876175             0.630480             0.147244          4.281858
# 7  -17.988733             0.631170             0.145307          4.343714
# 8   -8.635655             0.684203             0.154163          4.438183
# 9  -15.289476             0.747178             0.170324          4.386810

# %%
# comparing side-by-side result
result_df_list = []
num_samples = 10
for _ in range(num_samples):
  random_index = random.randint(0, len(sample_df) - 1)
  clue = sample_df['clue'].iloc[random_index]
  answer = sample_df['answer'].iloc[random_index]

  start_t = time.time()
  byt5_score = inference_model(model_byt5, tokenizer_byt5, clue, answer, "byt5")
  byt5_inf_time = time.time() - start_t

  start_t = time.time()
  t5_score = inference_model(model_t5, tokenizer_t5, clue, answer, "t5")
  t5_inf_time = time.time() - start_t

  result_df_list.append((clue, answer, byt5_score, t5_score, byt5_inf_time, t5_inf_time, byt5_inf_time / t5_inf_time))

  # print(f"BYT5 Score: CLUE is {clue} & POSITIVE ANSWER is {answer} ---> {byt5_score}")
  # print(f"T5 Score: CLUE is {clue} & POSITIVE ANSWER is {answer} ---> {t5_score}")
  # print()
result_df = pd.DataFrame(result_df_list, columns = ["Clue", 'Answer', 'ByT5 Score', 'T5 Score', 'ByT5 Inference Time', 'T5 Inference Time', 'T5 Time Factor'])
print(f"T5_small Model is {int(result_df['T5 Time Factor'].mean())} times faster than ByT5_small for single inference.")

result_df.head(10)
# Out:
# T5_small Model is 8 times faster than ByT5_small for single inference.
#                                            Clue               Answer  \
# 0                                   'tess' star               kinski
# 1                        see articles with hate               loathe
# 2                                    can't skip              must do
# 3                                         begot             fathered
# 4               note written without consonants                  iou
# 5  the only lottery urkel ever plays (wordplay)  theirishdweebstakes
# 6                    classic d.c. train station                union
# 7            kites bought in detroit (wordplay)        flying tigers
# 8                            comparatively well                haler
# 9                      planned social occasions              events,
#
#    ByT5 Score   T5 Score  ByT5 Inference Time  T5 Inference Time  \
# 0  -15.810485 -17.096556             0.558415           0.079601
# 1   -2.480923  -7.331069             0.671372           0.077159
# 2  -48.287979  -8.234839             0.529486           0.073305
# 3  -21.444815 -10.880735             0.448263           0.073695
# 4  -14.644562  -4.495320             0.751931           0.079365
# 5  -35.569160 -40.626554             0.990014           0.110854
# 6   -7.736264  -9.583914             0.635041           0.058219
# 7  -30.669530 -17.377535             0.578616           0.066761
# 8  -10.005526  -8.948947             0.398840           0.057228
# 9  -39.810776 -10.111033             0.461499           0.063823
#
#    T5 Time Factor
# 0        7.015174
# 1        8.701187
# 2        7.223091
# 3        6.082649
# 4        9.474369
# 5        8.930757
# 6       10.907805
# 7        8.666973
# 8        6.969304
# 9        7.230945

# %% [markdown]
# ---
# <center>T5_small Model is 8 times faster than ByT5_small for single inference.</center>
#
# ---

# %%
# testing if the byt5-reranker actually does gives score or not

# modification to be applied to positive answer to generate negative answers

def replace_random_chars(input_string, num_chars_to_replace):
    positions_to_replace = random.sample(range(len(input_string)), num_chars_to_replace)

    replaced_string = list(input_string)
    for position in positions_to_replace:
        replaced_string[position] = random.choice(string.ascii_letters.lower())

    return ''.join(replaced_string)

# random character omission from the input string

def remove_random_chars(input_string, num_chars_to_remove):
  positions_to_remove = random.sample(range(len(input_string)), 1)

  for i, pos in enumerate(positions_to_remove):
    input_string = input_string[:pos - i] + input_string[pos - i + 1 :]

  return input_string

# %%
# checking if the answer is a single valid word
spell = SpellChecker()

def get_alternate_solutions(answer):
  neg_answer_list = []
  if answer != '':
    # original single answer
    is_valid_word = spell.known([answer])

    # generating negative answers with single valid words
    if is_valid_word:
      # get two negative answers for single valid word
      for _ in range(3):
        if len(answer) >= 10:
          # concurrent two letter replacement
          neg_answer_with_replace = replace_random_chars(answer, 2 )
          neg_answer_list.append(neg_answer_with_replace.replace(' ', ''))

        else:
          # a single letter replacement
          neg_answer_with_replace = replace_random_chars(answer, 1)
          neg_answer_list.append(neg_answer_with_replace.replace(' ', ''))

      if len(answer) > 5:
        neg_answer_with_omission = remove_random_chars(answer, 1)
        neg_answer_list.append(neg_answer_with_omission.replace(' ', ''))

    # generate negative answers with unsegmented answers
    else:
      neg_answer_with_replace_list = []
      neg_answer_with_omission_list = []

      for _ in range(3):
        if len(answer) >= 15:
          neg_answer_with_replace_list.append(replace_random_chars(answer, 3))
          neg_answer_with_omission_list.append(remove_random_chars(answer, 2))

        if len(answer) >= 10:
          neg_answer_with_replace_list.append(replace_random_chars(answer, 2))
          neg_answer_with_omission_list.append(remove_random_chars(answer, 1))

        if len(answer) >= 5:
          neg_answer_with_replace_list.append(replace_random_chars(answer, 1))
          neg_answer_with_omission_list.append(remove_random_chars(answer, 1))

      for neg_answer in neg_answer_with_replace_list + neg_answer_with_omission_list:
        neg_answer_list.append(neg_answer.replace(' ', ''))
  return neg_answer_list

# %%
def compare_ans_with_neg_answer(model_, tokenizer_, sample_count, model_name, random_state = None):
  for _ in range(sample_count):
    if random_state is None:
      random_index = random.randint(0, len(sample_df) - 1)
    else:
      random_index = random_state

    clue = sample_df['clue'].iloc[random_index]
    answer = sample_df['answer'].iloc[random_index].replace(' ', '')
    neg_answer_list = get_alternate_solutions(answer)

    model_score = inference_model(model_, tokenizer_, clue, answer, model_name)
    print(f"{model_name} Score: Clue is '{clue}' & Postive Answer is '{answer}' ---> {model_score}")
    for neg_ans in neg_answer_list:
      model_score = inference_model(model_, tokenizer_, clue, neg_ans, model_name)
      print(f"{model_name} Score: Clue is '{clue}' & Negative Answer is [{neg_ans}] ---> {model_score}")
    print()

# %% [markdown]
# #### ByT5 scoring ability assessment and trend analysis with altered negative answers

# %%
compare_ans_with_neg_answer(model_byt5, tokenizer_byt5, 5, 'byt5')
# Out:
# byt5 Score: Clue is '"ships of inland commerce."' & Postive Answer is 'conestogawagons' ---> -13.34942626953125
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [cotestngawagonk] ---> -76.67035675048828
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conestogkwugons] ---> -55.5800666809082
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conestogawagrns] ---> -48.63178634643555
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conostoehwagons] ---> -55.121368408203125
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conesvogawagons] ---> -45.03205871582031
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conestogawagbns] ---> -45.45990753173828
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [confstogawrgops] ---> -66.52779388427734
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conesgogabagons] ---> -56.976646423339844
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conestogaqagons] ---> -37.67670822143555
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [cnestogawagons] ---> -30.69956660270691
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conestoawagons] ---> -37.713907957077026
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conestgawagons] ---> -42.90819525718689
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conesogawagons] ---> -29.782437086105347
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conestoawagons] ---> -37.713907957077026
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conetogawagons] ---> -31.506006717681885
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conestgawagons] ---> -42.90819525718689
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conetogawagons] ---> -31.506006717681885
# byt5 Score: Clue is '"ships of inland commerce."' & Negative Answer is [conestgawagons] ---> -42.90819525718689
#
# byt5 Score: Clue is 'watch old boy start game in court' & Postive Answer is 'observe' ---> -3.1091482639312744
# byt5 Score: Clue is 'watch old boy start game in court' & Negative Answer is [obeerve] ---> -43.55835723876953
# byt5 Score: Clue is 'watch old boy start game in court' & Negative Answer is [observi] ---> -16.59526824951172
# byt5 Score: Clue is 'watch old boy start game in court' & Negative Answer is [obzerve] ---> -25.540943145751953
# byt5 Score: Clue is 'watch old boy start game in court' & Negative Answer is [oberve] ---> -35.900474548339844
#
# byt5 Score: Clue is 'wrestling matches' & Postive Answer is 'meets' ---> -0.8701821863651276
# byt5 Score: Clue is 'wrestling matches' & Negative Answer is [meevs] ---> -33.89473056793213
# byt5 Score: Clue is 'wrestling matches' & Negative Answer is [meetz] ---> -18.188537120819092
# byt5 Score: Clue is 'wrestling matches' & Negative Answer is [oeets] ---> -28.159804344177246
#
# byt5 Score: Clue is 'twin-___ aircraft' & Postive Answer is 'engined' ---> -9.021350860595703
# byt5 Score: Clue is 'twin-___ aircraft' & Negative Answer is [enginbd] ---> -35.52073669433594
# byt5 Score: Clue is 'twin-___ aircraft' & Negative Answer is [englned] ---> -34.56393814086914
# byt5 Score: Clue is 'twin-___ aircraft' & Negative Answer is [enkined] ---> -26.25098991394043
# byt5 Score: Clue is 'twin-___ aircraft' & Negative Answer is [engine] ---> -6.323053181171417
# byt5 Score: Clue is 'twin-___ aircraft' & Negative Answer is [engied] ---> -25.596149921417236
# byt5 Score: Clue is 'twin-___ aircraft' & Negative Answer is [engied] ---> -25.596149921417236
#
# byt5 Score: Clue is 'destination of 1 across' & Postive Answer is 'mecca' ---> -6.056741952896118
# byt5 Score: Clue is 'destination of 1 across' & Negative Answer is [mwcca] ---> -26.30518341064453
# byt5 Score: Clue is 'destination of 1 across' & Negative Answer is [meccw] ---> -25.850014686584473
# byt5 Score: Clue is 'destination of 1 across' & Negative Answer is [mebca] ---> -32.81073474884033

# %% [markdown]
# #### Bart-base scoring ability assessment and treand analysis with altered negative answers

# %%
compare_ans_with_neg_answer(model_bart, tokenizer_bart, 15, 'byt5')
# Out:
# byt5 Score: Clue is 'summer stock unit (wordplay)' & Postive Answer is 'rerun' ---> -8.967248916625977
# byt5 Score: Clue is 'summer stock unit (wordplay)' & Negative Answer is [requn] ---> -25.049829483032227
# byt5 Score: Clue is 'summer stock unit (wordplay)' & Negative Answer is [refun] ---> -25.946245193481445
# byt5 Score: Clue is 'summer stock unit (wordplay)' & Negative Answer is [rerrn] ---> -31.57805633544922
#
# byt5 Score: Clue is 'nose about, taking notice, about to get close to listen' & Postive Answer is 'bendanear' ---> -22.35840368270874
# byt5 Score: Clue is 'nose about, taking notice, about to get close to listen' & Negative Answer is [beedanear] ---> -31.80578899383545
# byt5 Score: Clue is 'nose about, taking notice, about to get close to listen' & Negative Answer is [bendaneer] ---> -30.01490879058838
# byt5 Score: Clue is 'nose about, taking notice, about to get close to listen' & Negative Answer is [bendaneaa] ---> -39.51449203491211
# byt5 Score: Clue is 'nose about, taking notice, about to get close to listen' & Negative Answer is [benanear] ---> -30.18395185470581
# byt5 Score: Clue is 'nose about, taking notice, about to get close to listen' & Negative Answer is [bndanear] ---> -32.70584964752197
# byt5 Score: Clue is 'nose about, taking notice, about to get close to listen' & Negative Answer is [bendanea] ---> -33.526485443115234
#
# byt5 Score: Clue is 'remarkable praise for former name of country' & Postive Answer is 'persia' ---> -7.346780300140381
# byt5 Score: Clue is 'remarkable praise for former name of country' & Negative Answer is [pcrsia] ---> -27.150859832763672
# byt5 Score: Clue is 'remarkable praise for former name of country' & Negative Answer is [persiq] ---> -25.25379180908203
# byt5 Score: Clue is 'remarkable praise for former name of country' & Negative Answer is [persxa] ---> -31.226221084594727
# byt5 Score: Clue is 'remarkable praise for former name of country' & Negative Answer is [ersia] ---> -22.133943557739258
#
# byt5 Score: Clue is 'roulette, e.g' & Postive Answer is 'jeu' ---> -17.001224517822266
# byt5 Score: Clue is 'roulette, e.g' & Negative Answer is [jdu] ---> -19.320301055908203
# byt5 Score: Clue is 'roulette, e.g' & Negative Answer is [jei] ---> -20.170442581176758
# byt5 Score: Clue is 'roulette, e.g' & Negative Answer is [jey] ---> -17.82938003540039
#
# byt5 Score: Clue is 'the power   erotic album' & Postive Answer is 'ofsex' ---> -7.822771072387695
# byt5 Score: Clue is 'the power   erotic album' & Negative Answer is [oysex] ---> -24.982662200927734
# byt5 Score: Clue is 'the power   erotic album' & Negative Answer is [ohsex] ---> -20.817644119262695
# byt5 Score: Clue is 'the power   erotic album' & Negative Answer is [oqsex] ---> -33.513171672821045
# byt5 Score: Clue is 'the power   erotic album' & Negative Answer is [ofsx] ---> -21.874094009399414
# byt5 Score: Clue is 'the power   erotic album' & Negative Answer is [ofex] ---> -14.37189769744873
# byt5 Score: Clue is 'the power   erotic album' & Negative Answer is [ofsx] ---> -21.874094009399414
#
# byt5 Score: Clue is 'upbraided' & Postive Answer is 'yelledat' ---> -16.790807247161865
# byt5 Score: Clue is 'upbraided' & Negative Answer is [yelsedat] ---> -36.02098560333252
# byt5 Score: Clue is 'upbraided' & Negative Answer is [ymlledat] ---> -36.338839530944824
# byt5 Score: Clue is 'upbraided' & Negative Answer is [pelledat] ---> -25.048006057739258
# byt5 Score: Clue is 'upbraided' & Negative Answer is [yelleat] ---> -32.218050956726074
# byt5 Score: Clue is 'upbraided' & Negative Answer is [yelledt] ---> -21.527655124664307
# byt5 Score: Clue is 'upbraided' & Negative Answer is [elledat] ---> -21.038623809814453
#
# byt5 Score: Clue is 'outstanding chinese statesman.' & Postive Answer is 'koo' ---> -8.824745178222656
# byt5 Score: Clue is 'outstanding chinese statesman.' & Negative Answer is [koy] ---> -16.117403030395508
# byt5 Score: Clue is 'outstanding chinese statesman.' & Negative Answer is [koe] ---> -14.689939498901367
# byt5 Score: Clue is 'outstanding chinese statesman.' & Negative Answer is [hoo] ---> -11.145181655883789
#
# byt5 Score: Clue is 'divide.' & Postive Answer is 'splitup' ---> -11.265693664550781
# byt5 Score: Clue is 'divide.' & Negative Answer is [nplitup] ---> -42.2069091796875
# byt5 Score: Clue is 'divide.' & Negative Answer is [splijup] ---> -32.14439868927002
# byt5 Score: Clue is 'divide.' & Negative Answer is [splitjp] ---> -24.688682556152344
# byt5 Score: Clue is 'divide.' & Negative Answer is [spitup] ---> -19.57777738571167
# byt5 Score: Clue is 'divide.' & Negative Answer is [splitu] ---> -17.617206573486328
# byt5 Score: Clue is 'divide.' & Negative Answer is [splitu] ---> -17.617206573486328
#
# byt5 Score: Clue is 'tragus' & Postive Answer is 'earlet' ---> -11.175566673278809
# byt5 Score: Clue is 'tragus' & Negative Answer is [eorlet] ---> -27.016189575195312
# byt5 Score: Clue is 'tragus' & Negative Answer is [earlen] ---> -21.756460189819336
# byt5 Score: Clue is 'tragus' & Negative Answer is [earler] ---> -18.248502731323242
# byt5 Score: Clue is 'tragus' & Negative Answer is [erlet] ---> -19.43138313293457
# byt5 Score: Clue is 'tragus' & Negative Answer is [earet] ---> -18.874191284179688
# byt5 Score: Clue is 'tragus' & Negative Answer is [arlet] ---> -15.514206886291504
#
# byt5 Score: Clue is 'frightened' & Postive Answer is 'startled' ---> -5.034524440765381
# byt5 Score: Clue is 'frightened' & Negative Answer is [startley] ---> -20.278440475463867
# byt5 Score: Clue is 'frightened' & Negative Answer is [utartled] ---> -29.469635486602783
# byt5 Score: Clue is 'frightened' & Negative Answer is [starhled] ---> -29.61169719696045
# byt5 Score: Clue is 'frightened' & Negative Answer is [startld] ---> -26.785280227661133
#
# byt5 Score: Clue is 'muscle shaped like a greek letter, for short' & Postive Answer is 'delt' ---> -3.97880220413208
#
# byt5 Score: Clue is 'one alarmed in the morning (wordplay)' & Postive Answer is 'ariser' ---> -16.108932495117188
# byt5 Score: Clue is 'one alarmed in the morning (wordplay)' & Negative Answer is [arismr] ---> -27.439274787902832
# byt5 Score: Clue is 'one alarmed in the morning (wordplay)' & Negative Answer is [arisei] ---> -20.890026092529297
# byt5 Score: Clue is 'one alarmed in the morning (wordplay)' & Negative Answer is [aqiser] ---> -24.28083038330078
# byt5 Score: Clue is 'one alarmed in the morning (wordplay)' & Negative Answer is [arisr] ---> -26.428394317626953
# byt5 Score: Clue is 'one alarmed in the morning (wordplay)' & Negative Answer is [aiser] ---> -13.847285270690918
# byt5 Score: Clue is 'one alarmed in the morning (wordplay)' & Negative Answer is [aiser] ---> -13.847285270690918
#
# byt5 Score: Clue is 'jazz great' & Postive Answer is 'alhirt' ---> -15.386828422546387
# byt5 Score: Clue is 'jazz great' & Negative Answer is [aloirt] ---> -29.99714469909668
# byt5 Score: Clue is 'jazz great' & Negative Answer is [alsirt] ---> -29.05611801147461
# byt5 Score: Clue is 'jazz great' & Negative Answer is [alhijt] ---> -34.91102313995361
# byt5 Score: Clue is 'jazz great' & Negative Answer is [alhrt] ---> -23.615267276763916
# byt5 Score: Clue is 'jazz great' & Negative Answer is [alhir] ---> -22.58279323577881
# byt5 Score: Clue is 'jazz great' & Negative Answer is [ahirt] ---> -20.206501007080078
#
# byt5 Score: Clue is 'tonto's horse & international harvester suv' & Postive Answer is 'scout' ---> -8.159043312072754
# byt5 Score: Clue is 'tonto's horse & international harvester suv' & Negative Answer is [sxout] ---> -26.210896968841553
# byt5 Score: Clue is 'tonto's horse & international harvester suv' & Negative Answer is [scjut] ---> -27.58396863937378
# byt5 Score: Clue is 'tonto's horse & international harvester suv' & Negative Answer is [ecout] ---> -18.235177993774414
#
# byt5 Score: Clue is 'device displaying words to be read' & Postive Answer is 'autocue' ---> -26.080739498138428
# byt5 Score: Clue is 'device displaying words to be read' & Negative Answer is [artocue] ---> -30.0534725189209
# byt5 Score: Clue is 'device displaying words to be read' & Negative Answer is [autocue] ---> -26.080739498138428
# byt5 Score: Clue is 'device displaying words to be read' & Negative Answer is [autocfe] ---> -36.64898633956909
# byt5 Score: Clue is 'device displaying words to be read' & Negative Answer is [autoce] ---> -27.101045608520508
# byt5 Score: Clue is 'device displaying words to be read' & Negative Answer is [auocue] ---> -35.877394676208496
# byt5 Score: Clue is 'device displaying words to be read' & Negative Answer is [autoue] ---> -26.995773315429688

# %% [markdown]
# #### T5 scoring ability assessment and trend analysis with altered negative answers

# %%
compare_ans_with_neg_answer(model_t5, tokenizer_t5, 10, 't5')
# Out:
# t5 Score: Clue is 'e pluribus ___-' & Postive Answer is 'unum' ---> -10.301292657852173
# t5 Score: Clue is 'e pluribus ___-' & Negative Answer is [unue] ---> -16.40703582763672
# t5 Score: Clue is 'e pluribus ___-' & Negative Answer is [unus] ---> -10.94296145439148
# t5 Score: Clue is 'e pluribus ___-' & Negative Answer is [nnum] ---> -15.708335876464844
#
# t5 Score: Clue is 'typical new delhi worshiper' & Postive Answer is 'hindu' ---> -8.475731134414673
# t5 Score: Clue is 'typical new delhi worshiper' & Negative Answer is [htndu] ---> -25.649831295013428
# t5 Score: Clue is 'typical new delhi worshiper' & Negative Answer is [findu] ---> -20.646931171417236
# t5 Score: Clue is 'typical new delhi worshiper' & Negative Answer is [hitdu] ---> -21.162238597869873
#
# t5 Score: Clue is '"... ___ we extinguish sight and speech": browning' & Postive Answer is 'ere' ---> -1.9811012744903564
# t5 Score: Clue is '"... ___ we extinguish sight and speech": browning' & Negative Answer is [erw] ---> -13.385298728942871
# t5 Score: Clue is '"... ___ we extinguish sight and speech": browning' & Negative Answer is [erb] ---> -14.227988243103027
# t5 Score: Clue is '"... ___ we extinguish sight and speech": browning' & Negative Answer is [eru] ---> -10.490190505981445
#
# t5 Score: Clue is 'us slang for a wheel clamp' & Postive Answer is 'denverboot' ---> -21.33257293701172
# t5 Score: Clue is 'us slang for a wheel clamp' & Negative Answer is [denverbuoo] ---> -39.23057842254639
# t5 Score: Clue is 'us slang for a wheel clamp' & Negative Answer is [denverqoot] ---> -31.328978061676025
# t5 Score: Clue is 'us slang for a wheel clamp' & Negative Answer is [denvecbooc] ---> -41.80777359008789
# t5 Score: Clue is 'us slang for a wheel clamp' & Negative Answer is [denrerboot] ---> -30.141196250915527
# t5 Score: Clue is 'us slang for a wheel clamp' & Negative Answer is [dervekboot] ---> -32.517383098602295
# t5 Score: Clue is 'us slang for a wheel clamp' & Negative Answer is [denverbozt] ---> -39.327853202819824
# t5 Score: Clue is 'us slang for a wheel clamp' & Negative Answer is [deverboot] ---> -23.578292846679688
# t5 Score: Clue is 'us slang for a wheel clamp' & Negative Answer is [denverboo] ---> -25.423519134521484
# t5 Score: Clue is 'us slang for a wheel clamp' & Negative Answer is [denverbot] ---> -21.580915451049805
# t5 Score: Clue is 'us slang for a wheel clamp' & Negative Answer is [denverbot] ---> -21.580915451049805
# t5 Score: Clue is 'us slang for a wheel clamp' & Negative Answer is [denveroot] ---> -25.993003845214844
# t5 Score: Clue is 'us slang for a wheel clamp' & Negative Answer is [denverboo] ---> -25.423519134521484
#
# t5 Score: Clue is 'creamy candy.' & Postive Answer is 'fondant' ---> -15.985725402832031
# t5 Score: Clue is 'creamy candy.' & Negative Answer is [iondant] ---> -25.46444320678711
# t5 Score: Clue is 'creamy candy.' & Negative Answer is [fondaqt] ---> -31.611335277557373
# t5 Score: Clue is 'creamy candy.' & Negative Answer is [fondwnt] ---> -30.49943447113037
# t5 Score: Clue is 'creamy candy.' & Negative Answer is [ondant] ---> -21.2056827545166
#
# t5 Score: Clue is 'air word form' & Postive Answer is 'atmo' ---> -10.586629867553711
# t5 Score: Clue is 'air word form' & Negative Answer is [vtmo] ---> -24.505568504333496
# t5 Score: Clue is 'air word form' & Negative Answer is [atqo] ---> -19.93602180480957
# t5 Score: Clue is 'air word form' & Negative Answer is [atmh] ---> -17.911907196044922
#
# t5 Score: Clue is 'shakers mate' & Postive Answer is 'mover' ---> -9.501108884811401
# t5 Score: Clue is 'shakers mate' & Negative Answer is [movrr] ---> -26.582512855529785
# t5 Score: Clue is 'shakers mate' & Negative Answer is [kover] ---> -14.350637435913086
# t5 Score: Clue is 'shakers mate' & Negative Answer is [moeer] ---> -16.57178497314453
#
# t5 Score: Clue is 'he was going to help xtc' & Postive Answer is 'sgtrock' ---> -19.53440237045288
# t5 Score: Clue is 'he was going to help xtc' & Negative Answer is [sgtrocx] ---> -26.90331268310547
# t5 Score: Clue is 'he was going to help xtc' & Negative Answer is [sgtrocd] ---> -26.573608875274658
# t5 Score: Clue is 'he was going to help xtc' & Negative Answer is [sgtjock] ---> -23.49449133872986
# t5 Score: Clue is 'he was going to help xtc' & Negative Answer is [gtrock] ---> -19.62468385696411
# t5 Score: Clue is 'he was going to help xtc' & Negative Answer is [sgrock] ---> -24.144678115844727
# t5 Score: Clue is 'he was going to help xtc' & Negative Answer is [sgtrck] ---> -21.06551718711853
#
# t5 Score: Clue is 'someone else's kid compared to yours (wordplay)' & Postive Answer is 'brat' ---> -10.639106512069702
# t5 Score: Clue is 'someone else's kid compared to yours (wordplay)' & Negative Answer is [buat] ---> -19.752646923065186
# t5 Score: Clue is 'someone else's kid compared to yours (wordplay)' & Negative Answer is [nrat] ---> -15.254197120666504
# t5 Score: Clue is 'someone else's kid compared to yours (wordplay)' & Negative Answer is [braf] ---> -17.48577117919922
#
# t5 Score: Clue is 'clergyman prompt to restrain scoundrel' & Postive Answer is 'curate' ---> -8.940730333328247
# t5 Score: Clue is 'clergyman prompt to restrain scoundrel' & Negative Answer is [cusate] ---> -21.148151397705078
# t5 Score: Clue is 'clergyman prompt to restrain scoundrel' & Negative Answer is [curnte] ---> -27.287230491638184
# t5 Score: Clue is 'clergyman prompt to restrain scoundrel' & Negative Answer is [curare] ---> -18.587077617645264
# t5 Score: Clue is 'clergyman prompt to restrain scoundrel' & Negative Answer is [curae] ---> -17.188169479370117

# %% [markdown]
# Insight: So, a general trend with both BCS trained ByT5 and our T5-small is that the log probability or score for the positive answer is the lowest is counter for its absolute value.

# %% [markdown]
# #### Assessing the difference of scoring ability between fine-tuned 't5-small' and huggingface pretrained 't5-small' model.

# %%
# fine-tuned t5-small on partial clue-answer dataset
MODEL_T5 = 't5-small'
tokenizer_t5 = AutoTokenizer.from_pretrained(MODEL_T5)
model_t5 = T5ForConditionalGeneration.from_pretrained(T5_RANKER_PATH)

model_t5_pretrained = T5ForConditionalGeneration.from_pretrained(MODEL_T5)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
# side-by-side comparison between fine-tuned and the pre-trained T5-small model
result_df_list = []
num_samples = 10
for _ in range(num_samples):
  random_index = random.randint(0, len(sample_df) - 1)
  clue = sample_df['clue'].iloc[random_index]
  answer = sample_df['answer'].iloc[random_index]
  # clue = 'Q: ' + clue
  start_t = time.time()
  t5_finetuned_score = inference_model(model_t5, tokenizer_t5, clue, answer, "t5")
  t5_finetuned_inf_time = time.time() - start_t

  start_t = time.time()
  t5_pretrained_score = inference_model(model_t5_pretrained, tokenizer_t5, clue, answer, "t5")
  t5_pretrained_inf_time = time.time() - start_t

  result_df_list.append((clue, answer, t5_finetuned_score, t5_pretrained_score, t5_finetuned_inf_time, t5_pretrained_inf_time, t5_pretrained_inf_time / t5_finetuned_inf_time))
result_df = pd.DataFrame(result_df_list, columns = ["Clue", 'Answer', 'T5 (Fine-Tuned) Score', 'T5 (Pre-Trained) Score', 'T5 (Fine-Tuned) Inference Time', 'T5 (Pre-Trained) Inference Time', 'T5 Time Factor'])
# print(f"T5_small Model is {int(result_df['T5 Time Factor'].mean())} times faster than ByT5_small for single inference.")

result_df.head(10)
# Out:
#                                                 Clue        Answer  \
# 0                                  Q: was apathetic.         moped
# 1                    Q: two-time triple crown winner        arcaro
# 2                                  Q: burgundy wines          reds
# 3                     Q: 1996 christian slater movie  bed of roses
# 4                 Q: abbreviation in a help wanted a           eoe
# 5               Q: helpless rector departs in a huff         naked
# 6                             Q: kind of mattress pa      eggcrate
# 7  Q: certain class of artificial stimulants (wor...      strapons
# 8            Q: impressive note for a soprano to hit         highc
# 9                          Q: ararat director egoyan         a tom
#
#    T5 (Fine-Tuned) Score  T5 (Pre-Trained) Score  \
# 0              -8.274224              -26.979149
# 1             -11.990229              -39.967548
# 2              -3.969891              -16.500270
# 3             -15.735118              -42.545462
# 4              -8.428806              -23.418467
# 5              -7.801006              -24.093740
# 6             -14.155943              -39.775558
# 7             -21.392548              -34.377415
# 8             -13.788865              -29.816079
# 9              -8.966247              -23.298345
#
#    T5 (Fine-Tuned) Inference Time  T5 (Pre-Trained) Inference Time  \
# 0                        0.839202                         0.392857
# 1                        0.314405                         0.235514
# 2                        0.202767                         0.282063
# 3                        0.115350                         0.229063
# 4                        0.120671                         0.122185
# 5                        0.129929                         0.109075
# 6                        0.100059                         0.120623
# 7                        0.115667                         0.112806
# 8                        0.115679                         0.112956
# 9                        0.115884                         0.114532
#
#    T5 Time Factor
# 0        0.468132
# 1        0.749078
# 2        1.391071
# 3        1.985819
# 4        1.012548
# 5        0.839496
# 6        1.205512
# 7        0.975267
# 8        0.976461
# 9        0.988328

# %%
ran_index = 169

compare_ans_with_neg_answer(model_t5, tokenizer_t5, 1, 't5', ran_index)
compare_ans_with_neg_answer(model_t5_pretrained, tokenizer_t5, 1, 't5', ran_index)
# Out:
# t5 Score: Clue is 'included in selfie staggering out of spanish celebration' & Postive Answer is 'fiesta' ---> -6.63912034034729
# t5 Score: Clue is 'included in selfie staggering out of spanish celebration' & Negative Answer is [fievta] ---> -27.524006366729736
# t5 Score: Clue is 'included in selfie staggering out of spanish celebration' & Negative Answer is [fitsta] ---> -21.804675579071045
# t5 Score: Clue is 'included in selfie staggering out of spanish celebration' & Negative Answer is [fiemta] ---> -29.945266246795654
# t5 Score: Clue is 'included in selfie staggering out of spanish celebration' & Negative Answer is [festa] ---> -7.876183748245239
#
# t5 Score: Clue is 'included in selfie staggering out of spanish celebration' & Postive Answer is 'fiesta' ---> -23.506690979003906
# t5 Score: Clue is 'included in selfie staggering out of spanish celebration' & Negative Answer is [fiestt] ---> -26.880847930908203
# t5 Score: Clue is 'included in selfie staggering out of spanish celebration' & Negative Answer is [fxesta] ---> -31.339216232299805
# t5 Score: Clue is 'included in selfie staggering out of spanish celebration' & Negative Answer is [liesta] ---> -23.445751190185547
# t5 Score: Clue is 'included in selfie staggering out of spanish celebration' & Negative Answer is [iesta] ---> -23.53471279144287

# %% [markdown]
# Basically, the fine-tuned model has the ability to score lower for the positive answer in comparison to the pretrained fetch t5_small model.

# %% [markdown]
# #### Checking for the answer type and segmented answer / unsegmented answer status

# %%
clue_answer_df['segmented answer'] = clue_answer_df['answer'].apply(lambda x: x.replace(' ', '') if not isinstance(x, float) else x)

# %%
spaced_answer = []
for ans in clue_answer_df['segmented answer']:
  if not isinstance(ans, float):
    if ' ' in ans:
      spaced_answer.append(ans)
len(spaced_answer)
